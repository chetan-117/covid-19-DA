# %% [markdown]
# Q. 1) Show the number of Confirmed, Deaths and Recovered cases in each Region.
#
# Q. 2) Remove all the records where the Confirmed Cases is Less Than 10.
#
# Q. 3) In which Region, maximum number of Confirmed cases were recorded ?
#
# Q. 4) In which Region, minimum number of Deaths cases were recorded ?
#
# Q. 5) How many Confirmed, Deaths & Recovered cases were reported from India till 29 April 2020 ?
#
# Q. 6-A ) Sort the entire data wrt No. of Confirmed cases in ascending order.
#
# Q. 6-B ) Sort the entire data wrt No. of Recovered cases in descending order.

# %%
import pandas as pd

data = pd.read_csv('covid_19_data.csv')

data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
# visualizing the missing values
import seaborn as sns
import matplotlib.pyplot as plt 

sns.heatmap(data.isnull(), cmap='Accent')
plt.xticks(rotation='vertical')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       321 non-null    object
#  1   State      140 non-null    object
#  2   Region     321 non-null    object
#  3   Confirmed  321 non-null    int64
#  4   Deaths     321 non-null    int64
#  5   Recovered  321 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 15.2+ KB

# %%
# data.groupby('Region').value_counts()

data.groupby('Region').sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
# cases where the confirmed cases are more than 10

temp_data = data[~(data['Confirmed']<10)]

temp_data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
# region where max number of confirmed cases were recorded

temp_data = data.groupby("Region").sum()

temp_data[ temp_data['Confirmed'] == temp_data['Confirmed'].max() ]
# Out:
#         Confirmed  Deaths  Recovered
# Region
# US        1039909   60967     120720

# %%
# region where min number of deaths were recorded

# I can use the .groupby() method to group the result based on Region
data[ data['Deaths'] == data['Deaths'].min() ].groupby("Region").value_counts()
# Out:
# Region          Date       State                             Confirmed  Deaths  Recovered
# Australia       4/29/2020  Northern Territory                28         0       25           1
# Canada          4/29/2020  Grand Princess                    13         0       0            1
#                            Yukon                             11         0       0            1
#                            Recovered                         0          0       20327        1
#                            Prince Edward Island              27         0       0            1
#                            Northwest Territories             5          0       0            1
#                            New Brunswick                     118        0       0            1
# Denmark         4/29/2020  Greenland                         11         0       11           1
#                            Faroe Islands                     187        0       181          1
# ...

# %%
# cases from India till 29th April 2020

data[data['Region'] == 'India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437

# %%
# sorting data ascending order, based on confirmed cases 

data.groupby('Region')['Confirmed'].sum().sort_values(ascending=False)
# Out:
# Region
# US                       1039909
# Spain                     236899
# Italy                     203591
# France                    166543
# UK                        166441
#                           ...
# Sao Tome and Principe          8
# Papua New Guinea               8
# Bhutan                         7
# Western Sahara                 6
# Yemen                          6
# Name: Confirmed, Length: 187, dtype: int64

# %%
# sorting the whole data based on some column property

h_to_l_data = data.sort_values(by='Confirmed', ascending=True)

h_to_l_data
# Out:
#           Date                         State          Region  Confirmed  \
# 285  4/29/2020                     Recovered              US          0
# 284  4/29/2020                     Recovered          Canada          0
# 203  4/29/2020  Diamond Princess cruise ship          Canada          0
# 305  4/29/2020                         Tibet  Mainland China          1
# 289  4/29/2020     Saint Pierre and Miquelon          France          1
# ..         ...                           ...             ...        ...
# 57   4/29/2020                           NaN          France     165093
# 168  4/29/2020                           NaN              UK     165221
# 80   4/29/2020                           NaN           Italy     203591
# 153  4/29/2020                           NaN           Spain     236899
# 265  4/29/2020                      New York              US     299691
#
#      Deaths  Recovered
# 285       0     120720
# 284       0      20327
# 203       1          0
# ...

# %%
# sorting in descending based on Recovered Cases 
recovered_cases = data.sort_values(by='Recovered', ascending=False)

recovered_cases
# Out:
#           Date           State   Region  Confirmed  Deaths  Recovered
# 153  4/29/2020             NaN    Spain     236899   24275     132929
# 285  4/29/2020       Recovered       US          0       0     120720
# 61   4/29/2020             NaN  Germany     161539    6467     120400
# 76   4/29/2020             NaN     Iran      93657    5957      73791
# 80   4/29/2020             NaN    Italy     203591   27682      71252
# ..         ...             ...      ...        ...     ...        ...
# 248  4/29/2020        Maryland       US      20849    1078          0
# 246  4/29/2020        Manitoba   Canada        275       6          0
# 243  4/29/2020       Louisiana       US      27660    1845          0
# 241  4/29/2020        Kentucky       US       4537     234          0
# 215  4/29/2020  Grand Princess   Canada         13       0          0
#
# [321 rows x 6 columns]
